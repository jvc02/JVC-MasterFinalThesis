# %% [markdown]
# In this notebook, we experiment with a gating layer to a contrastive model in order to know which variables end up having less weight, and therefore, are less important when predicting $\texttt{VTE}$. The dataset that will be used is the fully imputed and pre‑processed dataset $\texttt{df\_ready}$. We first decide which learning rate and lambda values are best for prediction, and later on 10 experiments will be tried for 3 different values of lambda. This way, we'll see whether contrastive learning admits a gating layer in this dataset, and can decide which features are most important or not.
#
# The accuracy results from the predictions (ROC-AUC and PR-AUC) will be saved on $\texttt{results/7.contrastive\_gating}$ and the final weights results will be on $\texttt{results/7.final\_weights}$. A summary table is provided at the end of the notebook.

# %% [markdown]
# # Contrastive model with feature gating

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import os

import gc

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

from tqdm import tqdm

import matplotlib.pyplot as plt

from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    accuracy_score,
    classification_report,
    roc_curve,
    precision_recall_curve
)

# %% [markdown]
# ## Data loading

# %%
path_data = "dataframes\df_ready.csv"
df = pd.read_csv(path_data)

X = df.drop(columns=["VTE"]).values.astype(np.float32)
y = df["VTE"].values.astype(np.int64)

test_size = 0.25
random_state = 43

d_init = X.shape[1]
d_init
# Out:
# 39

# %% [markdown]
# ### Create the $\texttt{.csv}$ file

# %%
results_path = "results/7.contrastive_gating.csv"

# Check if file exists
if not os.path.exists(results_path):
    print("File not found. Creating new results file...")

    df_results = pd.DataFrame(columns=[
        "model",
        "random_state",
        "test_size",
        "n_epochs",
        "margin",
        "batch_size",
        "learning_rate",
        "weight_decay",
        "scheduler_step_size",
        "scheduler_gamma",
        "lambda_l1",
        "ROC-AUC",
        "PR-AUC",
        "Accuracy",
        "n_layers"
    ])

    df_results.to_csv(results_path, index=False)
else:
    print("Results file already exists.")
    df_results = pd.read_csv(results_path)

df_results.head()
# Out:
# Results file already exists.
#                 model  random_state  test_size  n_epochs  margin  batch_size  \
# 0  Contrastive+Gating             0       0.25       220     0.3          32
# 1  Contrastive+Gating             0       0.25       220     0.3          32
# 2  Contrastive+Gating             0       0.25       220     0.3          32
# 3  Contrastive+Gating             0       0.25       220     0.3          32
# 4  Contrastive+Gating             2       0.25       220     0.3          32
#
#    learning_rate  weight_decay  scheduler_step_size  scheduler_gamma  \
# 0         0.0001  1.000000e-08                  300             0.01
# 1         0.0005  1.000000e-08                  300             0.01
# 2         0.0005  1.000000e-08                  300             0.01
# 3         0.0005  1.000000e-08                  300             0.01
# 4         0.0005  1.000000e-08                  300             0.01
#
#    lambda_l1   ROC-AUC    PR-AUC  Accuracy  n_layers
# 0       0.10  0.536451  0.273388  0.703325         2
# 1       0.10  0.558499  0.290982  0.652174         2
# 2       0.20  0.560242  0.274870  0.677749         2
# 3       0.05  0.600249  0.307306  0.680307         2
# 4       0.10  0.538087  0.254034  0.667519         2

# %%
weights_path = "results/7.final_weights.csv"

# Check if file exists
if not os.path.exists(weights_path):
    print("File not found. Creating new results file...")

    df_weights = pd.DataFrame(columns=[
        "learning_rate",
        "weight_decay",
        "lambda_l1",
        "n_epochs",
        "n_layers",
        "margin",
        "test_size",
        "feature",
        "avg_weight"
    ])

    df_weights.to_csv(weights_path, index=False)
else:
    print("Results file already exists.")
    df_weights = pd.read_csv(weights_path)

df_weights.head()
# Out:
# Results file already exists.
#    learning_rate  weight_decay  lambda_l1  n_epochs  n_layers  margin  \
# 0          0.001  1.000000e-08        0.1       100         1     0.3
# 1          0.001  1.000000e-08        0.1       100         1     0.3
# 2          0.001  1.000000e-08        0.1       100         1     0.3
# 3          0.001  1.000000e-08        0.1       100         1     0.3
# 4          0.001  1.000000e-08        0.1       100         1     0.3
#
#    test_size                    feature  avg_weight
# 0       0.25      arterial_hypertension    0.083516
# 1       0.25                 pTNM_stage    0.081825
# 2       0.25  tobacco_use_Active smoker    0.080749
# 3       0.25   tumor_surgically_removed    0.080219
# 4       0.25         performance_status    0.079078

# %% [markdown]
# ## Kernel functions

# %% [markdown]
# ### Dataset classes

# %%
from utils import PairDatasetBalanced

# %% [markdown]
# ### Gating layer

# %%
from utils import GatingLayer

# %% [markdown]
# ### Model + loss

# %%
from utils import DeepKernel_gating, hinge_loss

# %% [markdown]
# ### Training / evaluation loops

# %%
from utils import train_one_epoch_gating, eval_one_epoch

# %% [markdown]
# ### Fit

# %%
from utils import fit_gating, plot_history, transform_dataset_contrastive

# %% [markdown]
# ## Training setup

# %% [markdown]
# ### Model variables

# %%
model_name="Contrastive+Gating_tune"
n_layers=1

FOLDS=4

bsize = 32
d_out = 16

learning_rate = 1e-3
weight_decay = 1e-8   # 1e-8

scheduler_step_size = 300
scheduler_gamma = 0.01

epochs = 100
margin = 0.3    

# scheduler = None    # disable for now

# L1 penalty
lambda_l1 = 0.05  # strength of an L1 regularization term

# %% [markdown]
# #### Device and empty cache

# %%
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# #### Define the StratifiedShuffleSplit

# %%
skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=random_state)

all_preds = []
all_y = []
all_probs = []

all_gating_weights = []

# %% [markdown]
# ## Training the model

# %%
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
    print(f"\nFold {fold + 1}")

    # Split the data into training and test sets for this fold
    # Flip train and test
    X_train_np = X[train_idx]
    X_test_np  = X[test_idx]
    y_train_np = y[train_idx]
    y_test_np  = y[test_idx]
    
    # Standardize (fit on train only)
    scaler = StandardScaler()                       # computes X_scaled = (X - mu) / sigma
    X_train_np = scaler.fit_transform(X_train_np)   # applied only on the training set
    X_test_np  = scaler.transform(X_test_np)   # is applied on the test set using training statistics
    # This avoids data leakage
    # Now all features have mean 0 and variance 1 (based on training data only)
    # Neural networks train much better with standardized inputs
    
    # Convert NumPy arrays into PyTorch tensors
    X_train = torch.tensor(X_train_np, dtype=torch.float32)
    y_train = torch.tensor(y_train_np, dtype=torch.long)
    X_test = torch.tensor(X_test_np, dtype=torch.float32)
    y_test = torch.tensor(y_test_np, dtype=torch.long)
    
    # Contrastive datasets/loaders
    # Each item returned by the dataset is a pair of samples (xa, xb) and their labels (ya, yb)
    # generate positive pairs (same class) and negative pairs (different class) in a controlled ratio
    train_dataset = PairDatasetBalanced(X_train, y_train)
    test_dataset = PairDatasetBalanced(X_test, y_test)

    # groups samples into batches of size bsize, shuffles the training dataset, feeds batches to the model efficiently
    pair_train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)
    pair_test_loader = DataLoader(test_dataset, batch_size=bsize)
    
    # Original loaders (for embeddings)
    # Return single samples (x, y) (no pairing, no contrastive sampling, no positive/negative logic)
    # To evaluate accuracy, F1, ROC-AUC, etc.
    train_original = TensorDataset(X_train, y_train)
    test_original = TensorDataset(X_test, y_test)
    original_train_loader = DataLoader(train_original, batch_size=bsize)
    original_test_loader = DataLoader(test_original, batch_size=bsize)

    # Free memory
    gc.collect()
    if device == "mps":
        torch.mps.empty_cache()
    if device == "cuda":
        torch.cuda.empty_cache()

    # learns a representation where “similar patients” are close and “different patients” are far
    model = DeepKernel_gating(d_init, d_out).to(device)

    # Creates an optimizer that will update the model parameters
    # AdamW is a variant of Adam that decouples weight decay from gradient updates
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=learning_rate,
        weight_decay=weight_decay
    )

    # learning rate scheduler that will reduce the learning rate during training
    scheduler = torch.optim.lr_scheduler.StepLR(
        optimizer,
        step_size=scheduler_step_size,
        gamma=scheduler_gamma
    )

    # Train the embedding model using pairwise hinge loss
    loss_fn = hinge_loss
    
    history = fit_gating(
        pair_train_loader, pair_test_loader,
        model, loss_fn, optimizer, device,
        epochs=epochs, margin=margin, lambda_l1=lambda_l1, threshold=0.2,
        scheduler=scheduler,
        verbose=False
    )

    w_fold = model.gating.v.detach().cpu().numpy()
    all_gating_weights.append(w_fold)

    # Plot training curves
    plot_history(history)

    # Transform the original dataset into embeddings
    X_t, y_t = transform_dataset_contrastive(model, original_train_loader, device)
    X_ts, y_ts = transform_dataset_contrastive(model, original_test_loader, device)

    # Use those embeddings for classification
    # random forest because embeddings are low‑dimensional (16 features), 
        # they are already structured (positives close, negatives far),
        # handles small datasets well, robust to noise and give probability outputs
    clf = RandomForestClassifier(
        n_estimators=101,
        max_depth=None,
        min_samples_split=2,
        random_state=random_state,
        class_weight="balanced"  # important for imbalanced VTE, ensures minority class is not ignored.
    )
    
    clf.fit(X_t, y_t)
    
    # This is supervised learning, but on top of the learned embedding space:
    # The contrastive model learns the geometry.
    # The classifier learns the decision boundary.

    yhat = clf.predict(X_ts)
    yhat_proba = clf.predict_proba(X_ts)

    all_preds.append(yhat)
    all_y.append(y_ts)
    all_probs.append(yhat_proba)
# Out:
# Fold 1
# Fold 2
# Fold 3
# Fold 4

# %% [markdown]
# ## Gating results

# %%
all_gating_weights = np.array(all_gating_weights)   # shape: (FOLDS, n_features)
avg_weights = all_gating_weights.mean(axis=0)

feature_names = df.columns.drop("VTE")

# %%
importance_df = pd.DataFrame({
    "feature": feature_names,
    "avg_weight": avg_weights
}).sort_values("avg_weight", ascending=False)

print(importance_df)
# Out:
#                                feature  avg_weight
# 3   grade_histological_differentiation    0.197803
# 35               primary_tumor_Gastric    0.193659
# 24                venous_insufficiency    0.190912
# 34            primary_tumor_Colorectal    0.189362
# 8             rs2227631_n_risk_alleles    0.188685
# 27                     catheter_device    0.187303
# 2                   performance_status    0.185184
# 32             primary_tumor_Bile duct    0.183796
# 1                                  bmi    0.179532
# 38            primary_tumor_Pancreatic    0.176486
# 16                                copd    0.170751
# 26            tumor_surgically_removed    0.170388
# 14                          pTNM_stage    0.168208
# 18               arterial_hypertension    0.167358
# 25               family_background_vte    0.164913
# 19                   diabetes_mellitus    0.164592
# 13               rs5985_n_risk_alleles    0.162623
# 23                        previous_ate    0.162136
# 28                                 sex    0.162104
# 10               rs5110_n_risk_alleles    0.161196
# 7                rs6003_n_risk_alleles    0.160130
# 0                        age_cancer_dx    0.159174
# 36                 primary_tumor_NSCLC    0.155250
# 20                        dyslipidemia    0.151359
# 6                rs4524_n_risk_alleles    0.151251
# 29           tobacco_use_Active smoker    0.149704
# 31        tobacco_use_Never has smoked    0.149689
# 5              rs169713_n_risk_alleles    0.147317
# 37           primary_tumor_Oesophageal    0.145275
# 30           tobacco_use_Former smoker    0.141909
# 12            rs2232698_n_risk_alleles    0.140722
# 4            rs11696364_n_risk_alleles    0.138987
# 11               rs6025_n_risk_alleles    0.132838
# 15       chronic_cardiac_insufficiency    0.116991
# 17                 renal_insufficiency    0.112358
# 22                        previous_vte    0.102134
# 21                     hormone_therapy    0.093561
# 9                 rs268_n_risk_alleles    0.084768
# 33                 primary_tumor_Brain    0.056935

# %% [markdown]
# ## Results and predictions

# %%
all_preds = np.concatenate(all_preds)
all_y = np.concatenate(all_y)
all_probs = np.concatenate(all_probs)

# %% [markdown]
# ### ROC, Precision-Recall curves and accuracy

# %%
roc_auc = roc_auc_score(all_y, all_probs[:, 1])
pr_auc = average_precision_score(all_y, all_probs[:, 1])
acc = accuracy_score(all_y, all_preds)

print("ROC-AUC:", roc_auc)
print("PR-AUC:", pr_auc)
print("Accuracy:", acc)
# Out:
# ROC-AUC: 0.4983819345661451
# PR-AUC: 0.25146004519708215
# Accuracy: 0.6521739130434783

# %%
print(classification_report(all_y, all_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78       296
#            1       0.22      0.17      0.19        95
#
#     accuracy                           0.65       391
#    macro avg       0.49      0.49      0.48       391
# weighted avg       0.62      0.65      0.64       391

# %%
# --- ROC CURVE ---
fpr, tpr, _ = roc_curve(all_y, all_probs[:, 1])

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], linestyle='--', linewidth=1)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - NN Embeddings + Random Forest")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# --- PRECISION-RECALL CURVE ---
precision, recall, _ = precision_recall_curve(all_y, all_probs[:, 1])

plt.figure(figsize=(6,5))
plt.plot(recall, precision, label=f"AP = {pr_auc:.3f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve - NN Embeddings + Random Forest")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Save results to the $\texttt{.csv}$

# %%
df_results.loc[len(df_results)] = [
    model_name,
    random_state,
    test_size,
    epochs,
    margin,
    bsize,
    learning_rate,
    weight_decay,
    scheduler_step_size,
    scheduler_gamma,
    lambda_l1,
    roc_auc,
    pr_auc,
    acc,
    n_layers
]

df_results.to_csv(results_path, index=False)
df_results.tail()
# Out:
#                       model  random_state  test_size  n_epochs  margin  \
# 91  Contrastive+Gating_tune            10       0.25       100     0.3
# 92  Contrastive+Gating_tune            15       0.25       100     0.3
# 93  Contrastive+Gating_tune            21       0.25       100     0.3
# 94  Contrastive+Gating_tune            42       0.25       100     0.3
# 95  Contrastive+Gating_tune            43       0.25       100     0.3
#
#     batch_size  learning_rate  weight_decay  scheduler_step_size  \
# 91          32          0.001  1.000000e-08                  300
# 92          32          0.001  1.000000e-08                  300
# 93          32          0.001  1.000000e-08                  300
# 94          32          0.001  1.000000e-08                  300
# 95          32          0.001  1.000000e-08                  300
#
#     scheduler_gamma  lambda_l1   ROC-AUC    PR-AUC  Accuracy  n_layers
# 91             0.01       0.05  0.576458  0.317587  0.693095         1
# 92             0.01       0.05  0.567621  0.289163  0.649616         1
# 93             0.01       0.05  0.565950  0.283979  0.682864         1
# 94             0.01       0.05  0.525196  0.280876  0.664962         1
# 95             0.01       0.05  0.498382  0.251460  0.652174         1

# %%
df_new = pd.DataFrame({
    "learning_rate": [learning_rate] * len(importance_df),
    "weight_decay": [weight_decay] * len(importance_df),
    "lambda_l1": [lambda_l1] * len(importance_df),
    "n_epochs": [epochs] * len(importance_df),
    "n_layers": [n_layers] * len(importance_df),
    "margin": [margin] * len(importance_df),
    "test_size": [test_size] * len(importance_df),
    "feature": importance_df["feature"].values,
    "avg_weight": importance_df["avg_weight"].values
})

df_weights = pd.concat([df_weights, df_new], ignore_index=True)
df_weights.to_csv(weights_path, index=False)

df_weights.tail()
# Out:
#       learning_rate  weight_decay  lambda_l1  n_epochs  n_layers  margin  \
# 1204          0.001  1.000000e-08       0.05       100         1     0.3
# 1205          0.001  1.000000e-08       0.05       100         1     0.3
# 1206          0.001  1.000000e-08       0.05       100         1     0.3
# 1207          0.001  1.000000e-08       0.05       100         1     0.3
# 1208          0.001  1.000000e-08       0.05       100         1     0.3
#
#       test_size               feature  avg_weight
# 1204       0.25   renal_insufficiency    0.112358
# 1205       0.25          previous_vte    0.102134
# 1206       0.25       hormone_therapy    0.093561
# 1207       0.25  rs268_n_risk_alleles    0.084768
# 1208       0.25   primary_tumor_Brain    0.056935

# %% [markdown]
# # Summary table

# %% [markdown]
# ### Accuracy results

# %%
summary = (
    df_results
    .groupby(["model", "learning_rate", "lambda_l1", "n_layers"])[["ROC-AUC", "PR-AUC", "Accuracy"]]
    .mean()
    .reset_index()
)

summary
# Out:
#                       model  learning_rate  lambda_l1  n_layers   ROC-AUC  \
# 0        Contrastive+Gating         0.0001       0.10         2  0.536451
# 1        Contrastive+Gating         0.0005       0.05         1  0.553880
# 2        Contrastive+Gating         0.0005       0.05         2  0.574583
# 3        Contrastive+Gating         0.0005       0.10         1  0.547799
# 4        Contrastive+Gating         0.0005       0.10         2  0.577510
# 5        Contrastive+Gating         0.0005       0.20         1  0.556120
# 6        Contrastive+Gating         0.0005       0.20         2  0.564054
# 7        Contrastive+Gating         0.0010       0.05         1  0.568094
# 8        Contrastive+Gating         0.0010       0.05         2  0.566711
# 9        Contrastive+Gating         0.0010       0.10         1  0.580605
# 10       Contrastive+Gating         0.0010       0.10         2  0.574239
# 11       Contrastive+Gating         0.0010       0.20         1  0.566817
# 12       Contrastive+Gating         0.0010       0.20         2  0.554975
# 13  Contrastive+Gating_tune         0.0010       0.05         1  0.559320
# 14  Contrastive+Gating_tune         0.0010       0.10         1  0.552781
# 15  Contrastive+Gating_tune         0.0010       0.20         1  0.567157
#
#       PR-AUC  Accuracy
# 0   0.273388  0.703325
# 1   0.287666  0.689003
# 2   0.302308  0.688710
# 3   0.277992  0.673657
# 4   0.303800  0.687980
# 5   0.290853  0.688491
# 6   0.292640  0.694629
# 7   0.312953  0.686957
# 8   0.301439  0.683376
# 9   0.310396  0.698210
# 10  0.303431  0.682864
# 11  0.303530  0.699233
# 12  0.283059  0.686445
# 13  0.298125  0.680772
# 14  0.290606  0.686445
# 15  0.296262  0.692072

# %% [markdown]
# ### Final weights

# %%
grouped = (
    df_weights
    .groupby(["feature", "lambda_l1"])["avg_weight"]
    .mean()
    .reset_index()
)

t01 = grouped[grouped["lambda_l1"] == 0.1][["feature", "avg_weight"]] \
        .sort_values("avg_weight", ascending=False) \
        .reset_index(drop=True)

t02 = grouped[grouped["lambda_l1"] == 0.2][["feature", "avg_weight"]] \
        .sort_values("avg_weight", ascending=False) \
        .reset_index(drop=True)

t03 = grouped[grouped["lambda_l1"] == 0.05][["feature", "avg_weight"]] \
        .sort_values("avg_weight", ascending=False) \
        .reset_index(drop=True)

final_table = pd.concat(
    [
        t01.rename(columns={"feature": "feature_0.1", "avg_weight": "avg_weight_0.1"}),
        t02.rename(columns={"feature": "feature_0.2", "avg_weight": "avg_weight_0.2"}),
        t03.rename(columns={"feature": "feature_0.3", "avg_weight": "avg_weight_0.3"})
    ],
    axis=1
)

final_table
# Out:
#                            feature_0.1  avg_weight_0.1  \
# 0                                  sex        0.083789
# 1                           pTNM_stage        0.076199
# 2                   performance_status        0.075876
# 3                                  bmi        0.073216
# 4             primary_tumor_Colorectal        0.073175
# 5            tobacco_use_Former smoker        0.070768
# 6                arterial_hypertension        0.070513
# 7              rs169713_n_risk_alleles        0.069888
# 8            tobacco_use_Active smoker        0.069839
# 9         tobacco_use_Never has smoked        0.069397
# 10                     catheter_device        0.069391
# 11  grade_histological_differentiation        0.069377
# 12            tumor_surgically_removed        0.069057
# 13            rs2227631_n_risk_alleles        0.068496
# 14                       age_cancer_dx        0.068414
# 15            primary_tumor_Pancreatic        0.067999
# 16               primary_tumor_Gastric        0.067300
# 17               rs5985_n_risk_alleles        0.066506
# 18             primary_tumor_Bile duct        0.065971
# 19                   diabetes_mellitus        0.064983
# 20               rs4524_n_risk_alleles        0.064974
# 21                venous_insufficiency        0.064933
# 22                                copd        0.063895
# 23                        previous_ate        0.063692
# 24               family_background_vte        0.063661
# 25                        dyslipidemia        0.061399
# 26                 primary_tumor_NSCLC        0.061148
# 27               rs5110_n_risk_alleles        0.061143
# 28               rs6003_n_risk_alleles        0.059506
# 29           primary_tumor_Oesophageal        0.058764
# 30           rs11696364_n_risk_alleles        0.053973
# 31            rs2232698_n_risk_alleles        0.046085
# 32                 renal_insufficiency        0.043924
# 33                        previous_vte        0.043237
# 34               rs6025_n_risk_alleles        0.042022
# 35                rs268_n_risk_alleles        0.040634
# 36       chronic_cardiac_insufficiency        0.039546
# 37                     hormone_therapy        0.039298
# 38                 primary_tumor_Brain        0.023541
#
#                            feature_0.2  avg_weight_0.2  \
# 0                                  sex        0.034779
# 1                           pTNM_stage        0.030337
# 2                                  bmi        0.029579
# 3   grade_histological_differentiation        0.029332
# 4            tobacco_use_Active smoker        0.028430
# 5             rs2227631_n_risk_alleles        0.027315
# 6                         previous_ate        0.027231
# 7              rs169713_n_risk_alleles        0.027035
# 8                   performance_status        0.026995
# 9             tumor_surgically_removed        0.026840
# 10             primary_tumor_Bile duct        0.026647
# 11                   diabetes_mellitus        0.026519
# 12        tobacco_use_Never has smoked        0.026383
# 13               rs4524_n_risk_alleles        0.026317
# 14            primary_tumor_Colorectal        0.025972
# 15               arterial_hypertension        0.025816
# 16                       age_cancer_dx        0.025747
# 17               family_background_vte        0.025680
# 18               rs5110_n_risk_alleles        0.025678
# 19            primary_tumor_Pancreatic        0.025382
# 20           tobacco_use_Former smoker        0.025138
# 21                                copd        0.025136
# 22                     catheter_device        0.025097
# 23                venous_insufficiency        0.023577
# 24           primary_tumor_Oesophageal        0.023398
# 25                 primary_tumor_NSCLC        0.023394
# 26               rs5985_n_risk_alleles        0.023337
# 27               rs6003_n_risk_alleles        0.022989
# 28                        dyslipidemia        0.022468
# 29               primary_tumor_Gastric        0.022340
# 30           rs11696364_n_risk_alleles        0.018318
# 31            rs2232698_n_risk_alleles        0.017961
# 32                 renal_insufficiency        0.016052
# 33               rs6025_n_risk_alleles        0.014951
# 34                rs268_n_risk_alleles        0.013844
# 35       chronic_cardiac_insufficiency        0.013707
# 36                        previous_vte        0.013623
# 37                     hormone_therapy        0.011706
# 38                 primary_tumor_Brain        0.005111
#
#                            feature_0.3  avg_weight_0.3
# 0                                  sex        0.193284
# 1                   performance_status        0.189436
# 2             primary_tumor_Colorectal        0.185204
# 3                           pTNM_stage        0.184539
# 4   grade_histological_differentiation        0.177887
# 5             primary_tumor_Pancreatic        0.169110
# 6                                  bmi        0.167068
# 7             rs2227631_n_risk_alleles        0.166272
# 8                      catheter_device        0.166173
# 9            tobacco_use_Active smoker        0.164453
# 10             rs169713_n_risk_alleles        0.164434
# 11        tobacco_use_Never has smoked        0.164425
# 12            tumor_surgically_removed        0.163503
# 13                        previous_ate        0.163502
# 14               primary_tumor_Gastric        0.162443
# 15                 primary_tumor_NSCLC        0.159708
# 16               family_background_vte        0.158594
# 17                   diabetes_mellitus        0.157949
# 18                       age_cancer_dx        0.157623
# 19               arterial_hypertension        0.157095
# 20               rs5110_n_risk_alleles        0.156742
# 21             primary_tumor_Bile duct        0.156712
# 22                venous_insufficiency        0.156129
# 23           tobacco_use_Former smoker        0.153839
# 24                                copd        0.153770
# 25               rs5985_n_risk_alleles        0.153587
# 26               rs6003_n_risk_alleles        0.150413
# 27                        dyslipidemia        0.150391
# 28           primary_tumor_Oesophageal        0.146164
# 29               rs4524_n_risk_alleles        0.146112
# 30           rs11696364_n_risk_alleles        0.140849
# 31               rs6025_n_risk_alleles        0.126777
# 32            rs2232698_n_risk_alleles        0.121159
# 33                 renal_insufficiency        0.117425
# 34                rs268_n_risk_alleles        0.103227
# 35                        previous_vte        0.101475
# 36                     hormone_therapy        0.101272
# 37       chronic_cardiac_insufficiency        0.092553
# 38                 primary_tumor_Brain        0.069427
